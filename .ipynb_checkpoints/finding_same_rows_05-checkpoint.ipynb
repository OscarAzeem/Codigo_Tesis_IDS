# %%
import pandas as pd
from my_classes_02 import Metodos_Thesis as MT
pd.set_option('display.max_columns', 50)
mc=MT()
dataset=pd.read_csv("./dataset_labeled/kdd_testing_labeled.csv")

# %% [markdown]
# mc.encuentra_filas_iguales(dataset,fin='DstHostSrvRerrorRate')

# %%
mc.encuentra_filas_iguales(dataset,fin='DstHostSrvRerrorRate')
# Out:
# ***PREPROCESSING***
# Building the labels dimension number= 1, perteneciente al Nombre: ProtocolType
# Building the labels dimension number= 2, perteneciente al Nombre: Service
# Building the labels dimension number= 3, perteneciente al Nombre: Flag
# ***VALORES REPETIDOS***
# Existen 233813 valores repetidos
# ***NUEVA REPETICION en el indice suma: -506.283331
# Tiene un total de instancias iguales a: 3
# No de instancia: 0 que equivale al indice dataset: 34988
# Pertenece al tipo de ataque: saint. de la clase probe
# No de instancia: 1 que equivale al indice dataset: 34990
# Pertenece al tipo de ataque: saint. de la clase probe
# No de instancia: 2 que equivale al indice dataset: 35190
# Pertenece al tipo de ataque: saint. de la clase probe
#       TypeOfAttack  Group  IndexAttack  IndexByGroup  IndexBinary        suma
# 34988       saint.  probe           24             3            1 -506.283331
# 34990       saint.  probe           24             3            1 -506.283331
# ...

# %%
print(dataset.loc[[34988,34990,35190]])
# Out:
#        Duration ProtocolType  Service Flag  SourceBytes  DestinationBytes  \
# 34988         0          tcp  private  REJ            0                 0
# 34990         0          tcp  private  REJ            0                 0
# 35190         0          tcp  private  REJ            0                 0
#
#        Land  WrongFragment  Urgent  Hot  FailedLogins  LoggedIn  \
# 34988     0              0       0    0             0         0
# 34990     0              0       0    0             0         0
# 35190     0              0       0    0             0         0
#
#        NumberOfCompromised  RootShell  SuAttempted  Root  \
# 34988                    0          0            0     0
# 34990                    0          0            0     0
# 35190                    0          0            0     0
#
#        NumberOfFileCreations  NumberOfShellPrompts  NumberOfAccessFiles  \
# 34988                      0                     0                    0
# ...

# %%
with pd.option_context('display.max_rows', None, 'display.max_columns', 42):
    print(dataset.loc[[34988,34990,35190],'TypeOfAttack':])
# Out:
#       TypeOfAttack  Group  IndexAttack  IndexByGroup  IndexBinary
# 34988       saint.  probe           24             3            1
# 34990       saint.  probe           24             3            1
# 35190       saint.  probe           24             3            1

# %%
a=[34988,34990,35190]

# %%
with pd.option_context('display.max_rows', None, 'display.max_columns', 42):
    print(dataset.loc[a,'TypeOfAttack':])
# Out:
#       TypeOfAttack  Group  IndexAttack  IndexByGroup  IndexBinary
# 34988       saint.  probe           24             3            1
# 34990       saint.  probe           24             3            1
# 35190       saint.  probe           24             3            1

# %%
b=[]

# %%
b=[b,1]

# %%
b
# Out:
# [[], 1]

# %%
b[0]
# Out:
# []

# %%
b=[10]

# %%
b=[b,10]
b
# Out:
# [[[[[[[[[[[[[[[10], 10], 10], 10], 10], 10], 10], 10], 10], 10], 10], 10], 10],
#   10],
#  10]

# %%
b[0]
# Out:
# [[[[[[[[[[[[[[10], 10], 10], 10], 10], 10], 10], 10], 10], 10], 10], 10], 10],
#  10]

# %%
b[2]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-38-a6e0636a165a> in <module>()
# ----> 1 b[2]
#
# IndexError: list index out of range

# %%
b=[10]

# %%
b.append(20)

# %%
b
# Out:
# [10, 20]

# %%
b.append(30)

# %%
b.append(40)

# %%
b
# Out:
# [10, 20, 30, 40]

# %%
c=[50,100]

# %%
b.append(c)

# %%
b
# Out:
# [10, 20, [50, 100]]

# %%
b[0]
# Out:
# 10

# %%
b[1]
# Out:
# 20

# %%
b[2]
# Out:
# [50, 100]
