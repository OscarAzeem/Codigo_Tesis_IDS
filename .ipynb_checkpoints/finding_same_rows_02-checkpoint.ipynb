# %%
import pandas as pd
import numpy as np
from my_classes_01 import Metodos_Thesis as MT
mc=MT()
dataset=pd.read_csv("./dataset_labeled/nsl_testing_labeled.csv")
pd.set_option('display.max_columns', 50)

# %%
def registros_iguales_2(dataset_inicio,inicio,fin):
    from sklearn import preprocessing
    dataset=dataset_inicio.loc[:,inicio:fin]
    columnas=dataset.columns
    print("***PREPROCESSING***")
    for indice in range(0,len(columnas)):
        if type(dataset.loc[0,columnas[indice]]) == str:
            print('Building the labels dimension number= %d, perteneciente al Nombre: %s' % (indice,columnas[indice]))
            #print('Nombre %s' % (columnas[indice]))
            #print('Su tipo es %s=' % (str(type(data))))
            #label enconder, object
            label_encoder=preprocessing.LabelEncoder()
            #label encoer, fit
            label_encoder.fit(dataset[columnas[indice]])
            #building the dataframe
            dataset[columnas[indice]]=label_encoder.transform(dataset[columnas[indice]])
    #obteniendo la suma del dataset
    suma=dataset.sum(axis=1)
    #adding the "suma" series to the dataset_inicio 
    dataset_inicio["suma"]=suma
    #borrando los duplicados
    series_suma=dataset_inicio[dataset_inicio.suma.duplicated(keep=False)]
    #obteniendo los valores repetidos mediante group by
    series_suma=dataset_inicio.groupby('suma').apply(lambda x: list(x.index))
    #
    print("***VALORES REPETIDOS***")
    print("Existen %d de valores repetidos" % (len(dataset_inicio)-len(series_suma)))
    #arriba todo bien
    for indice in range(0,len(series_suma)):
        if len(series_suma[series_suma.index.values[indice]]) > 1:
            print("NUEVA REPETICION en el indice suma: %d" %(series_suma.index.values[indice]))
            print("Tiene un total de instancias iguales a: %d" %(len(series_suma[series_suma.index.values[indice]])))
            #aqui parece el problema
            for cantidad_instancias_repetidas in range(0,len(series_suma[series_suma.index.values[indice]])):
                print("No de instancia: %d que equivale al indice dataset: %d" %(cantidad_instancias_repetidas,series_suma[series_suma.index.values[indice]][cantidad_instancias_repetidas]))
                ataque=dataset_inicio.loc[series_suma[series_suma.index.values[indice]][cantidad_instancias_repetidas],"TypeOfAttack"]
                clase=dataset_inicio.loc[series_suma[series_suma.index.values[indice]][cantidad_instancias_repetidas],"Group"]
                print("Pertenece al tipo de ataque: %s de la clase %s" %(ataque, clase))

# %% [markdown]
# # No coincide con emacs al primer momento ya que el csv tiene una fila de más: nombre de las columnas
# # Y el indice en pandas empieza en cero, el numero seria +2
# # si la coincidencia es en: 9471+2=9473

# %%
inicio='Duration'
fin='IndexBinary'
dataset_inicio=dataset

# %%
dataset_inicio=dataset_inicio.drop(['TimesApparead'],axis=1)

# %%
from sklearn import preprocessing
dataset=dataset_inicio.loc[:,inicio:fin]
columnas=dataset.columns
print("***PREPROCESSING***")
for indice in range(0,len(columnas)):
    if type(dataset.loc[0,columnas[indice]]) == str:
        print('Building the labels dimension number= %d, perteneciente al Nombre: %s' % (indice,columnas[indice]))
        #print('Nombre %s' % (columnas[indice]))
        #print('Su tipo es %s=' % (str(type(data))))
        #label enconder, object
        label_encoder=preprocessing.LabelEncoder()
        #label encoer, fit
        label_encoder.fit(dataset[columnas[indice]])
        #building the dataframe
        dataset[columnas[indice]]=label_encoder.transform(dataset[columnas[indice]])*(np.random.randn()+np.random.randint(low=1,high=100))

        
#falta multiplicar cada una de las columnas por una distinta variacion, debido que hay parametros en los +1 y -1

        
        
#obteniendo la suma del dataset
suma=dataset.sum(axis=1)
#adding the "suma" series to the dataset_inicio 
dataset_inicio["suma"]=suma
#borrando los duplicados
series_suma=dataset_inicio[dataset_inicio.suma.duplicated(keep=False)]
#obteniendo los valores repetidos mediante group by
series_suma=dataset_inicio.groupby('suma').apply(lambda x: list(x.index))
#
print("***VALORES REPETIDOS***")
print("Existen %d de valores repetidos" % (len(dataset_inicio)-len(series_suma)))
#arriba todo bien
for indice in range(0,len(series_suma)):
    if len(series_suma[series_suma.index.values[indice]]) > 1:
        print("NUEVA REPETICION en el indice suma: %f" %(series_suma.index.values[indice]))
        print("Tiene un total de instancias iguales a: %d" %(len(series_suma[series_suma.index.values[indice]])))
        #aqui parece el problema
        for cantidad_instancias_repetidas in range(0,len(series_suma[series_suma.index.values[indice]])):
            print("No de instancia: %d que equivale al indice dataset: %d" %(cantidad_instancias_repetidas,series_suma[series_suma.index.values[indice]][cantidad_instancias_repetidas]))
            ataque=dataset_inicio.loc[series_suma[series_suma.index.values[indice]][cantidad_instancias_repetidas],"TypeOfAttack"]
            clase=dataset_inicio.loc[series_suma[series_suma.index.values[indice]][cantidad_instancias_repetidas],"Group"]
            print("Pertenece al tipo de ataque: %s de la clase %s" %(ataque, clase))
# Out:
# ***PREPROCESSING***
# Building the labels dimension number= 1, perteneciente al Nombre: ProtocolType
# Building the labels dimension number= 2, perteneciente al Nombre: Service
# Building the labels dimension number= 3, perteneciente al Nombre: Flag
# Building the labels dimension number= 41, perteneciente al Nombre: TypeOfAttack
# Building the labels dimension number= 42, perteneciente al Nombre: Group
# ***VALORES REPETIDOS***
# Existen 1962 de valores repetidos
# NUEVA REPETICION en el indice suma: 1221.729941
# Tiene un total de instancias iguales a: 2
# No de instancia: 0 que equivale al indice dataset: 9471
# Pertenece al tipo de ataque: land de la clase dos
# No de instancia: 1 que equivale al indice dataset: 18529
# Pertenece al tipo de ataque: land de la clase dos
# NUEVA REPETICION en el indice suma: 1375.309830
# Tiene un total de instancias iguales a: 2
# No de instancia: 0 que equivale al indice dataset: 516
# Pertenece al tipo de ataque: ipsweep de la clase probe
# No de instancia: 1 que equivale al indice dataset: 19314
# Pertenece al tipo de ataque: ipsweep de la clase probe
# NUEVA REPETICION en el indice suma: 1402.299830
# Tiene un total de instancias iguales a: 2
# No de instancia: 0 que equivale al indice dataset: 145
# Pertenece al tipo de ataque: ipsweep de la clase probe
# No de instancia: 1 que equivale al indice dataset: 20552
# Pertenece al tipo de ataque: ipsweep de la clase probe
# NUEVA REPETICION en el indice suma: 1439.299830
# Tiene un total de instancias iguales a: 2
# No de instancia: 0 que equivale al indice dataset: 9157
# Pertenece al tipo de ataque: ipsweep de la clase probe
# No de instancia: 1 que equivale al indice dataset: 12644
# Pertenece al tipo de ataque: ipsweep de la clase probe
# NUEVA REPETICION en el indice suma: 1527.658640
# Tiene un total de instancias iguales a: 2
# No de instancia: 0 que equivale al indice dataset: 2341
# Pertenece al tipo de ataque: neptune de la clase dos
# No de instancia: 1 que equivale al indice dataset: 3821
# Pertenece al tipo de ataque: neptune de la clase dos
# NUEVA REPETICION en el indice suma: 1619.668807
# Tiene un total de instancias iguales a: 2
# No de instancia: 0 que equivale al indice dataset: 5195
# Pertenece al tipo de ataque: apache2 de la clase dos
# No de instancia: 1 que equivale al indice dataset: 12830
# Pertenece al tipo de ataque: apache2 de la clase dos
# NUEVA REPETICION en el indice suma: 1627.668807
# Tiene un total de instancias iguales a: 2
# No de instancia: 0 que equivale al indice dataset: 12225
# Pertenece al tipo de ataque: apache2 de la clase dos
# No de instancia: 1 que equivale al indice dataset: 18070
# Pertenece al tipo de ataque: apache2 de la clase dos
# NUEVA REPETICION en el indice suma: 1637.668807
# Tiene un total de instancias iguales a: 2
# No de instancia: 0 que equivale al indice dataset: 12743
# Pertenece al tipo de ataque: apache2 de la clase dos
# No de instancia: 1 que equivale al indice dataset: 19910
# Pertenece al tipo de ataque: apache2 de la clase dos
# NUEVA REPETICION en el indice suma: 1659.628807
# Tiene un total de instancias iguales a: 2
# No de instancia: 0 que equivale al indice dataset: 5591
# Pertenece al tipo de ataque: apache2 de la clase dos
# No de instancia: 1 que equivale al indice dataset: 14223
# Pertenece al tipo de ataque: apache2 de la clase dos
# NUEVA REPETICION en el indice suma: 1661.628807
# Tiene un total de instancias iguales a: 2
# No de instancia: 0 que equivale al indice dataset: 891
# Pertenece al tipo de ataque: apache2 de la clase dos
# No de instancia: 1 que equivale al indice dataset: 13592
# Pertenece al tipo de ataque: apache2 de la clase dos
# NUEVA REPETICION en el indice suma: 1675.628807
# Tiene un total de instancias iguales a: 2
# No de instancia: 0 que equivale al indice dataset: 11108
# Pertenece al tipo de ataque: apache2 de la clase dos
# No de instancia: 1 que equivale al indice dataset: 12656
# Pertenece al tipo de ataque: apache2 de la clase dos
# NUEVA REPETICION en el indice suma: 1695.628807
# Tiene un total de instancias iguales a: 2
# No de instancia: 0 que equivale al indice dataset: 18641
# Pertenece al tipo de ataque: apache2 de la clase dos
# No de instancia: 1 que equivale al indice dataset: 22514
# Pertenece al tipo de ataque: apache2 de la clase dos
# NUEVA REPETICION en el indice suma: 1697.628807
# Tiene un total de instancias iguales a: 2
# No de instancia: 0 que equivale al indice dataset: 202
# Pertenece al tipo de ataque: apache2 de la clase dos
# No de instancia: 1 que equivale al indice dataset: 22182
# Pertenece al tipo de ataque: apache2 de la clase dos
# NUEVA REPETICION en el indice suma: 1699.628807
# Tiene un total de instancias iguales a: 2
# No de instancia: 0 que equivale al indice dataset: 5642
# Pertenece al tipo de ataque: apache2 de la clase dos
# No de instancia: 1 que equivale al indice dataset: 12940
# Pertenece al tipo de ataque: apache2 de la clase dos
# NUEVA REPETICION en el indice suma: 1713.776258
# Tiene un total de instancias iguales a: 2
# No de instancia: 0 que equivale al indice dataset: 2917
# Pertenece al tipo de ataque: neptune de la clase dos
# No de instancia: 1 que equivale al indice dataset: 20360
# Pertenece al tipo de ataque: neptune de la clase dos
# NUEVA REPETICION en el indice suma: 1754.104127
# Tiene un total de instancias iguales a: 2
# No de instancia: 0 que equivale al indice dataset: 737
# Pertenece al tipo de ataque: normal de la clase normal
# No de instancia: 1 que equivale al indice dataset: 2365
# Pertenece al tipo de ataque: normal de la clase normal
# NUEVA REPETICION en el indice suma: 1850.980570
# Tiene un total de instancias iguales a: 2
# No de instancia: 0 que equivale al indice dataset: 3964
# Pertenece al tipo de ataque: mscan de la clase probe
# No de instancia: 1 que equivale al indice dataset: 4320
# Pertenece al tipo de ataque: mscan de la clase probe
# NUEVA REPETICION en el indice suma: 1855.558495
# Tiene un total de instancias iguales a: 2
# No de instancia: 0 que equivale al indice dataset: 6379
# Pertenece al tipo de ataque: guess_passwd de la clase r2l
# No de instancia: 1 que equivale al indice dataset: 17922
# Pertenece al tipo de ataque: guess_passwd de la clase r2l
# NUEVA REPETICION en el indice suma: 1947.659157
# Tiene un total de instancias iguales a: 2
# No de instancia: 0 que equivale al indice dataset: 217
# Pertenece al tipo de ataque: normal de la clase normal
# No de instancia: 1 que equivale al indice dataset: 3323
# Pertenece al tipo de ataque: normal de la clase normal
# NUEVA REPETICION en el indice suma: 1947.707082
# Tiene un total de instancias iguales a: 2
# No de instancia: 0 que equivale al indice dataset: 283
# Pertenece al tipo de ataque: mscan de la clase probe
# No de instancia: 1 que equivale al indice dataset: 8331
# Pertenece al tipo de ataque: mscan de la clase probe
# NUEVA REPETICION en el indice suma: 2089.954174
# Tiene un total de instancias iguales a: 2
# No de instancia: 0 que equivale al indice dataset: 15200
# Pertenece al tipo de ataque: neptune de la clase dos
# No de instancia: 1 que equivale al indice dataset: 19453
# Pertenece al tipo de ataque: neptune de la clase dos
# NUEVA REPETICION en el indice suma: 2143.841680
# Tiene un total de instancias iguales a: 2
# No de instancia: 0 que equivale al indice dataset: 591
# Pertenece al tipo de ataque: httptunnel de la clase u2r
# No de instancia: 1 que equivale al indice dataset: 7513
# Pertenece al tipo de ataque: httptunnel de la clase u2r
# NUEVA REPETICION en el indice suma: 2145.861680
# Tiene un total de instancias iguales a: 2
# No de instancia: 0 que equivale al indice dataset: 1914
# Pertenece al tipo de ataque: httptunnel de la clase u2r
# No de instancia: 1 que equivale al indice dataset: 5305
# Pertenece al tipo de ataque: httptunnel de la clase u2r
# NUEVA REPETICION en el indice suma: 2146.861680
# Tiene un total de instancias iguales a: 2
# No de instancia: 0 que equivale al indice dataset: 12358
# Pertenece al tipo de ataque: httptunnel de la clase u2r
# No de instancia: 1 que equivale al indice dataset: 17078
# Pertenece al tipo de ataque: httptunnel de la clase u2r
# NUEVA REPETICION en el indice suma: 2150.901680
# Tiene un total de instancias iguales a: 2
# No de instancia: 0 que equivale al indice dataset: 4782
# Pertenece al tipo de ataque: httptunnel de la clase u2r
# No de instancia: 1 que equivale al indice dataset: 9759
# Pertenece al tipo de ataque: httptunnel de la clase u2r
# NUEVA REPETICION en el indice suma: 2154.921680
# Tiene un total de instancias iguales a: 2
# No de instancia: 0 que equivale al indice dataset: 13194
# Pertenece al tipo de ataque: httptunnel de la clase u2r
# No de instancia: 1 que equivale al indice dataset: 17070
# Pertenece al tipo de ataque: httptunnel de la clase u2r
# NUEVA REPETICION en el indice suma: 2246.029157
# Tiene un total de instancias iguales a: 2
# No de instancia: 0 que equivale al indice dataset: 11295
# Pertenece al tipo de ataque: normal de la clase normal
# No de instancia: 1 que equivale al indice dataset: 16721
# Pertenece al tipo de ataque: normal de la clase normal
# NUEVA REPETICION en el indice suma: 2252.699157
# Tiene un total de instancias iguales a: 2
# No de instancia: 0 que equivale al indice dataset: 21621
# Pertenece al tipo de ataque: normal de la clase normal
# No de instancia: 1 que equivale al indice dataset: 21963
# Pertenece al tipo de ataque: normal de la clase normal
# NUEVA REPETICION en el indice suma: 2263.679157
# Tiene un total de instancias iguales a: 2
# No de instancia: 0 que equivale al indice dataset: 7708
# Pertenece al tipo de ataque: normal de la clase normal
# No de instancia: 1 que equivale al indice dataset: 15980
# Pertenece al tipo de ataque: normal de la clase normal
# NUEVA REPETICION en el indice suma: 2264.729157
# Tiene un total de instancias iguales a: 2
# No de instancia: 0 que equivale al indice dataset: 762
# Pertenece al tipo de ataque: normal de la clase normal
# No de instancia: 1 que equivale al indice dataset: 7789
# Pertenece al tipo de ataque: normal de la clase normal
# NUEVA REPETICION en el indice suma: 2288.459157
# Tiene un total de instancias iguales a: 2
# No de instancia: 0 que equivale al indice dataset: 2556
# Pertenece al tipo de ataque: normal de la clase normal
# No de instancia: 1 que equivale al indice dataset: 5408
# Pertenece al tipo de ataque: normal de la clase normal
# NUEVA REPETICION en el indice suma: 2289.469157
# Tiene un total de instancias iguales a: 2
# No de instancia: 0 que equivale al indice dataset: 1708
# Pertenece al tipo de ataque: normal de la clase normal
# No de instancia: 1 que equivale al indice dataset: 10504
# Pertenece al tipo de ataque: normal de la clase normal
# NUEVA REPETICION en el indice suma: 2291.509157
# Tiene un total de instancias iguales a: 2
# No de instancia: 0 que equivale al indice dataset: 3633
# Pertenece al tipo de ataque: normal de la clase normal
# No de instancia: 1 que equivale al indice dataset: 20260
# Pertenece al tipo de ataque: normal de la clase normal
# NUEVA REPETICION en el indice suma: 2311.519157
# Tiene un total de instancias iguales a: 2
# No de instancia: 0 que equivale al indice dataset: 15470
# Pertenece al tipo de ataque: normal de la clase normal
# No de instancia: 1 que equivale al indice dataset: 17319
# Pertenece al tipo de ataque: normal de la clase normal
# NUEVA REPETICION en el indice suma: 2313.189157
# Tiene un total de instancias iguales a: 2
# No de instancia: 0 que equivale al indice dataset: 12132
# Pertenece al tipo de ataque: normal de la clase normal
# No de instancia: 1 que equivale al indice dataset:
# Tiene un total de instancias iguales a: 2
# No de instancia: 0 que equivale al indice dataset: 11997
# Pertenece al tipo de ataque: normal de la clase normal
# No de instancia: 1 que equivale al indice dataset: 20539
# Pertenece al tipo de ataque: normal de la clase normal
# NUEVA REPETICION en el indice suma: 15080.813664
# Tiene un total de instancias iguales a: 2
# No de instancia: 0 que equivale al indice dataset: 8339
# Pertenece al tipo de ataque: normal de la clase normal
# No de instancia: 1 que equivale al indice dataset: 17838
# Pertenece al tipo de ataque: normal de la clase normal
# NUEVA REPETICION en el indice suma: 15823.813664
# Tiene un total de instancias iguales a: 2
# No de instancia: 0 que equivale al indice dataset: 6154
# Pertenece al tipo de ataque: normal de la clase normal
# No de instancia: 1 que equivale al indice dataset: 16381
# Pertenece al tipo de ataque: normal de la clase normal
# NUEVA REPETICION en el indice suma: 64534.729024
# Tiene un total de instancias iguales a: 2
# No de instancia: 0 que equivale al indice dataset: 14201
# Pertenece al tipo de ataque: back de la clase dos
# No de instancia: 1 que equivale al indice dataset: 21827
# Pertenece al tipo de ataque: back de la clase dos
# NUEVA REPETICION en el indice suma: 64541.839024
# Tiene un total de instancias iguales a: 2
# No de instancia: 0 que equivale al indice dataset: 7234
# Pertenece al tipo de ataque: back de la clase dos
# No de instancia: 1 que equivale al indice dataset: 10003
# Pertenece al tipo de ataque: back de la clase dos
# NUEVA REPETICION en el indice suma: 64544.839024
# Tiene un total de instancias iguales a: 2
# No de instancia: 0 que equivale al indice dataset: 1212
# Pertenece al tipo de ataque: back de la clase dos
# No de instancia: 1 que equivale al indice dataset: 18712
# Pertenece al tipo de ataque: back de la clase dos
# NUEVA REPETICION en el indice suma: 64545.839024
# Tiene un total de instancias iguales a: 2
# No de instancia: 0 que equivale al indice dataset: 6046
# Pertenece al tipo de ataque: back de la clase dos
# No de instancia: 1 que equivale al indice dataset: 9938
# Pertenece al tipo de ataque: back de la clase dos
# NUEVA REPETICION en el indice suma: 64548.889024
# Tiene un total de instancias iguales a: 2
# No de instancia: 0 que equivale al indice dataset: 12152
# Pertenece al tipo de ataque: back de la clase dos
# No de instancia: 1 que equivale al indice dataset: 21778
# Pertenece al tipo de ataque: back de la clase dos
# NUEVA REPETICION en el indice suma: 64549.859024
# Tiene un total de instancias iguales a: 2
# No de instancia: 0 que equivale al indice dataset: 6296
# Pertenece al tipo de ataque: back de la clase dos
# No de instancia: 1 que equivale al indice dataset: 10831
# Pertenece al tipo de ataque: back de la clase dos
# NUEVA REPETICION en el indice suma: 64551.889024
# Tiene un total de instancias iguales a: 3
# No de instancia: 0 que equivale al indice dataset: 5934
# Pertenece al tipo de ataque: back de la clase dos
# No de instancia: 1 que equivale al indice dataset: 7646
# Pertenece al tipo de ataque: back de la clase dos
# No de instancia: 2 que equivale al indice dataset: 13770
# Pertenece al tipo de ataque: back de la clase dos
# NUEVA REPETICION en el indice suma: 64552.529024
# Tiene un total de instancias iguales a: 2
# No de instancia: 0 que equivale al indice dataset: 8142
# Pertenece al tipo de ataque: back de la clase dos
# No de instancia: 1 que equivale al indice dataset: 21997
# Pertenece al tipo de ataque: back de la clase dos
# NUEVA REPETICION en el indice suma: 64553.889024
# Tiene un total de instancias iguales a: 2
# No de instancia: 0 que equivale al indice dataset: 2732
# Pertenece al tipo de ataque: back de la clase dos
# No de instancia: 1 que equivale al indice dataset: 18575
# Pertenece al tipo de ataque: back de la clase dos
# NUEVA REPETICION en el indice suma: 64554.369024
# Tiene un total de instancias iguales a: 2
# No de instancia: 0 que equivale al indice dataset: 862
# Pertenece al tipo de ataque: back de la clase dos
# No de instancia: 1 que equivale al indice dataset: 13649
# Pertenece al tipo de ataque: back de la clase dos
# NUEVA REPETICION en el indice suma: 64555.229024
# Tiene un total de instancias iguales a: 2
# No de instancia: 0 que equivale al indice dataset: 2336
# Pertenece al tipo de ataque: back de la clase dos
# No de instancia: 1 que equivale al indice dataset: 9825
# Pertenece al tipo de ataque: back de la clase dos
# NUEVA REPETICION en el indice suma: 64555.889024
# Tiene un total de instancias iguales a: 2
# No de instancia: 0 que equivale al indice dataset: 5670
# Pertenece al tipo de ataque: back de la clase dos
# No de instancia: 1 que equivale al indice dataset: 15007
# Pertenece al tipo de ataque: back de la clase dos
# NUEVA REPETICION en el indice suma: 64556.149024
# Tiene un total de instancias iguales a: 2
# No de instancia: 0 que equivale al indice dataset: 3193
# Pertenece al tipo de ataque: back de la clase dos
# No de instancia: 1 que equivale al indice dataset: 16744
# Pertenece al tipo de ataque: back de la clase dos
# NUEVA REPETICION en el indice suma: 64573.979024
# Tiene un total de instancias iguales a: 2
# No de instancia: 0 que equivale al indice dataset: 15521
# Pertenece al tipo de ataque: back de la clase dos
# No de instancia: 1 que equivale al indice dataset: 19296
# Pertenece al tipo de ataque: back de la clase dos
# NUEVA REPETICION en el indice suma: 64861.722178
# Tiene un total de instancias iguales a: 2
# No de instancia: 0 que equivale al indice dataset: 7217
# Pertenece al tipo de ataque: apache2 de la clase dos
# No de instancia: 1 que equivale al indice dataset: 11978
# Pertenece al tipo de ataque: apache2 de la clase dos
# NUEVA REPETICION en el indice suma: 286792.535662
# Tiene un total de instancias iguales a: 5
# No de instancia: 0 que equivale al indice dataset: 7522
# Pertenece al tipo de ataque: warezmaster de la clase r2l
# No de instancia: 1 que equivale al indice dataset: 10989
# Pertenece al tipo de ataque: warezmaster de la clase r2l
# No de instancia: 2 que equivale al indice dataset: 12772
# Pertenece al tipo de ataque: warezmaster de la clase r2l
# No de instancia: 3 que equivale al indice dataset: 20933
# Pertenece al tipo de ataque: warezmaster de la clase r2l
# No de instancia: 4 que equivale al indice dataset: 21766
# Pertenece al tipo de ataque: warezmaster de la clase r2l
# NUEVA REPETICION en el indice suma: 286794.535662
# Tiene un total de instancias iguales a: 2
# No de instancia: 0 que equivale al indice dataset: 10088
# Pertenece al tipo de ataque: warezmaster de la clase r2l
# No de instancia: 1 que equivale al indice dataset: 20605
# Pertenece al tipo de ataque: warezmaster de la clase r2l
# NUEVA REPETICION en el indice suma: 286795.535662
# Tiene un total de instancias iguales a: 2
# No de instancia: 0 que equivale al indice dataset: 3717
# Pertenece al tipo de ataque: warezmaster de la clase r2l
# No de instancia: 1 que equivale al indice dataset: 16850
# Pertenece al tipo de ataque: warezmaster de la clase r2l
# NUEVA REPETICION en el indice suma: 286796.535662
# Tiene un total de instancias iguales a: 2
# No de instancia: 0 que equivale al indice dataset: 3334
# Pertenece al tipo de ataque: warezmaster de la clase r2l
# No de instancia: 1 que equivale al indice dataset: 14347
# Pertenece al tipo de ataque: warezmaster de la clase r2l
# NUEVA REPETICION en el indice suma: 286797.035662
# Tiene un total de instancias iguales a: 2
# No de instancia: 0 que equivale al indice dataset: 5437
# Pertenece al tipo de ataque: warezmaster de la clase r2l
# No de instancia: 1 que equivale al indice dataset: 11159
# Pertenece al tipo de ataque: warezmaster de la clase r2l
# NUEVA REPETICION en el indice suma: 286798.535662
# Tiene un total de instancias iguales a: 2
# No de instancia: 0 que equivale al indice dataset: 11680
# Pertenece al tipo de ataque: warezmaster de la clase r2l
# No de instancia: 1 que equivale al indice dataset: 21930
# Pertenece al tipo de ataque: warezmaster de la clase r2l
# NUEVA REPETICION en el indice suma: 286799.535662
# Tiene un total de instancias iguales a: 2
# No de instancia: 0 que equivale al indice dataset: 5446
# Pertenece al tipo de ataque: warezmaster de la clase r2l
# No de instancia: 1 que equivale al indice dataset: 19383
# Pertenece al tipo de ataque: warezmaster de la clase r2l
# NUEVA REPETICION en el indice suma: 286800.755662
# Tiene un total de instancias iguales a: 2
# No de instancia: 0 que equivale al indice dataset: 7721
# Pertenece al tipo de ataque: warezmaster de la clase r2l
# No de instancia: 1 que equivale al indice dataset: 8245
# Pertenece al tipo de ataque: warezmaster de la clase r2l
# NUEVA REPETICION en el indice suma: 286800.865662
# Tiene un total de instancias iguales a: 2
# No de instancia: 0 que equivale al indice dataset: 7194
# Pertenece al tipo de ataque: warezmaster de la clase r2l
# No de instancia: 1 que equivale al indice dataset: 14423
# Pertenece al tipo de ataque: warezmaster de la clase r2l
# NUEVA REPETICION en el indice suma: 286802.535662
# Tiene un total de instancias iguales a: 2
# No de instancia: 0 que equivale al indice dataset: 8162
# Pertenece al tipo de ataque: warezmaster de la clase r2l
# No de instancia: 1 que equivale al indice dataset: 9630
# Pertenece al tipo de ataque: warezmaster de la clase r2l
# NUEVA REPETICION en el indice suma: 286804.735662
# Tiene un total de instancias iguales a: 2
# No de instancia: 0 que equivale al indice dataset: 701
# Pertenece al tipo de ataque: warezmaster de la clase r2l
# No de instancia: 1 que equivale al indice dataset: 17713
# Pertenece al tipo de ataque: warezmaster de la clase r2l
# NUEVA REPETICION en el indice suma: 286804.785662
# Tiene un total de instancias iguales a: 2
# No de instancia: 0 que equivale al indice dataset: 4478
# Pertenece al tipo de ataque: warezmaster de la clase r2l
# No de instancia: 1 que equivale al indice dataset: 21965
# Pertenece al tipo de ataque: warezmaster de la clase r2l
# NUEVA REPETICION en el indice suma: 286806.535662
# Tiene un total de instancias iguales a: 2
# No de instancia: 0 que equivale al indice dataset: 15293
# Pertenece al tipo de ataque: warezmaster de la clase r2l
# No de instancia: 1 que equivale al indice dataset: 16964
# Pertenece al tipo de ataque: warezmaster de la clase r2l
# NUEVA REPETICION en el indice suma: 286806.735662
# Tiene un total de instancias iguales a: 2
# No de instancia: 0 que equivale al indice dataset: 4311
# Pertenece al tipo de ataque: warezmaster de la clase r2l
# No de instancia: 1 que equivale al indice dataset: 19868
# Pertenece al tipo de ataque: warezmaster de la clase r2l
# NUEVA REPETICION en el indice suma: 286807.535662
# Tiene un total de instancias iguales a: 2
# No de instancia: 0 que equivale al indice dataset: 16808
# Pertenece al tipo de ataque: warezmaster de la clase r2l
# No de instancia: 1 que equivale al indice dataset: 17142
# Pertenece al tipo de ataque: warezmaster de la clase r2l
# NUEVA REPETICION en el indice suma: 286808.705662
# Tiene un total de instancias iguales a: 2
# No de instancia: 0 que equivale al indice dataset: 6086
# Pertenece al tipo de ataque: warezmaster de la clase r2l
# No de instancia: 1 que equivale al indice dataset: 20727
# Pertenece al tipo de ataque: warezmaster de la clase r2l
# NUEVA REPETICION en el indice suma: 286808.745662
# Tiene un total de instancias iguales a: 2
# No de instancia: 0 que equivale al indice dataset: 16464
# Pertenece al tipo de ataque: warezmaster de la clase r2l
# No de instancia: 1 que equivale al indice dataset: 20396
# Pertenece al tipo de ataque: warezmaster de la clase r2l
# NUEVA REPETICION en el indice suma: 286810.705662
# Tiene un total de instancias iguales a: 2
# No de instancia: 0 que equivale al indice dataset: 5931
# Pertenece al tipo de ataque: warezmaster de la clase r2l
# No de instancia: 1 que equivale al indice dataset: 14278
# Pertenece al tipo de ataque: warezmaster de la clase r2l
# NUEVA REPETICION en el indice suma: 286810.745662
# Tiene un total de instancias iguales a: 2
# No de instancia: 0 que equivale al indice dataset: 4249
# Pertenece al tipo de ataque: warezmaster de la clase r2l
# No de instancia: 1 que equivale al indice dataset: 14949
# Pertenece al tipo de ataque: warezmaster de la clase r2l
# NUEVA REPETICION en el indice suma: 286812.675662
# Tiene un total de instancias iguales a: 2
# No de instancia: 0 que equivale al indice dataset: 1921
# Pertenece al tipo de ataque: warezmaster de la clase r2l
# No de instancia: 1 que equivale al indice dataset: 12040
# Pertenece al tipo de ataque: warezmaster de la clase r2l
# NUEVA REPETICION en el indice suma: 286816.735662
# Tiene un total de instancias iguales a: 2
# No de instancia: 0 que equivale al indice dataset: 7817
# Pertenece al tipo de ataque: warezmaster de la clase r2l
# No de instancia: 1 que equivale al indice dataset: 14341
# Pertenece al tipo de ataque: warezmaster de la clase r2l
# NUEVA REPETICION en el indice suma: 286818.535662
# Tiene un total de instancias iguales a: 2
# No de instancia: 0 que equivale al indice dataset: 7243
# Pertenece al tipo de ataque: warezmaster de la clase r2l
# No de instancia: 1 que equivale al indice dataset: 7887
# Pertenece al tipo de ataque: warezmaster de la clase r2l
# NUEVA REPETICION en el indice suma: 286818.705662
# Tiene un total de instancias iguales a: 3
# No de instancia: 0 que equivale al indice dataset: 5729
# Pertenece al tipo de ataque: warezmaster de la clase r2l
# No de instancia: 1 que equivale al indice dataset: 5867
# Pertenece al tipo de ataque: warezmaster de la clase r2l
# No de instancia: 2 que equivale al indice dataset: 9087
# Pertenece al tipo de ataque: warezmaster de la clase r2l
# NUEVA REPETICION en el indice suma: 286820.685662
# Tiene un total de instancias iguales a: 2
# No de instancia: 0 que equivale al indice dataset: 4766
# Pertenece al tipo de ataque: warezmaster de la clase r2l
# No de instancia: 1 que equivale al indice dataset: 14122
# Pertenece al tipo de ataque: warezmaster de la clase r2l
# NUEVA REPETICION en el indice suma: 286824.665662
# Tiene un total de instancias iguales a: 2
# No de instancia: 0 que equivale al indice dataset: 17272
# Pertenece al tipo de ataque: warezmaster de la clase r2l
# No de instancia: 1 que equivale al indice dataset: 20898
# Pertenece al tipo de ataque: warezmaster de la clase r2l
# NUEVA REPETICION en el indice suma: 286824.685662
# Tiene un total de instancias iguales a: 2
# No de instancia: 0 que equivale al indice dataset: 8850
# Pertenece al tipo de ataque: warezmaster de la clase r2l
# No de instancia: 1 que equivale al indice dataset: 21697
# Pertenece al tipo de ataque: warezmaster de la clase r2l

# %%
dataset_inicio.loc[[9471,18529],:]
# Out:
#        Duration ProtocolType Service Flag  SourceBytes  DestinationBytes  \
# 9471          0          tcp  finger   S0            0                 0
# 18529         0          tcp  finger   S0            0                 0
#
#        Land  WrongFragment  Urgent  Hot  FailedLogins  LoggedIn  \
# 9471      1              0       0    0             0         0
# 18529     1              0       0    0             0         0
#
#        NumberOfCompromised  RootShell  SuAttempted  Root  \
# 9471                     0          0            0     0
# 18529                    0          0            0     0
#
#        NumberOfFileCreations  NumberOfShellPrompts  NumberOfAccessFiles  \
# 9471                       0                     0                    0
# 18529                      0                     0                    0
#
#        NumberOfOutbound  IsHotLogin  IsGuestLogin  Count  SrvCount  \
# 9471                  0           0             0      1         2
# 18529                 0           0             0      1         3
#
#        SerrorRate  SrvSerrorRate  RerrorRate  SrvRerrorRate  SameSrvRate  \
# 9471          1.0            1.0         0.0            0.0          1.0
# 18529         1.0            1.0         0.0            0.0          1.0
#
#        DiffSrvRate  SrvDiffHostRate  DstHostCount  DstHostSrvCount  \
# 9471           0.0              1.0             1                3
# 18529          0.0              1.0             1                2
#
#        DstHostSameSrvRate  DstHostDiffSrvRate  DstHostSameSrcPortRate  \
# 9471                  1.0                 0.0                     1.0
# 18529                 1.0                 0.0                     1.0
#
#        DstHostSrvDiffHostRate  DstHostSerrorRate  DstHostSrvSerrorRate  \
# 9471                      1.0                1.0                   1.0
# 18529                     1.0                1.0                   1.0
#
#        DstHostRerrorRate  DstHostSrvRerrorRate TypeOfAttack Group  \
# 9471                 0.0                   0.0         land   dos
# 18529                0.0                   0.0         land   dos
#
#        IndexAttack  IndexByGroup  IndexBinary         suma
# 9471             8             1            1  1099.724483
# 18529            8             1            1  1099.724483

# %%
dataset.loc[[12349,21710],:]
# Out:
#        Duration  ProtocolType      Service        Flag  SourceBytes  \
# 12349         0     59.622352 -3614.932548 -217.792612          121
# 21710         0     59.622352 -3614.932548 -217.792612          125
#
#        DestinationBytes  Land  WrongFragment  Urgent  Hot     ...       \
# 12349               174     0              0       0    0     ...
# 21710               174     0              0       0    0     ...
#
#        DstHostSerrorRate  DstHostSrvSerrorRate  DstHostRerrorRate  \
# 12349                0.0                   0.0                0.0
# 21710                0.0                   0.0                0.0
#
#        DstHostSrvRerrorRate  TypeOfAttack  TimesApparead       Group  \
# 12349                  0.04    332.651977              9 -279.433228
# 21710                  0.05    332.651977              8 -279.433228
#
#        IndexAttack  IndexByGroup  IndexBinary
# 12349            4             4            1
# 21710            4             4            1
#
# [2 rows x 47 columns]

# %%
t1=dataset.loc[3445,:]

# %%
t1.sum()
# Out:
# 116.16

# %%
t2=dataset.loc[9666,:]

# %%
t2.sum()
# Out:
# 116.16

# %% [markdown]
# # el problema esta en el label encoder, hay que asginar valores más grandes

# %%
#multiplicando por un valor random unicamente las columnas en las que fue usada el label encoder

# %%
np.random.randint(low=20,high=80)
# Out:
# 76
