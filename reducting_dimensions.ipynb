# %%
import matplotlib.pyplot as plt
import pandas as pd

from sklearn.decomposition import PCA as sklearnPCA
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis as LDA
from sklearn.datasets.samples_generator import make_blobs

from pandas.tools.plotting import parallel_coordinates

# %%
url = 'https://archive.ics.uci.edu/ml/machine-learning-databases/wine/wine.data'
cols =  ['Class', 'Alcohol', 'MalicAcid', 'Ash', 'AlcalinityOfAsh', 'Magnesium', 'TotalPhenols', 
         'Flavanoids', 'NonflavanoidPhenols', 'Proanthocyanins', 'ColorIntensity', 
         'Hue', 'OD280/OD315', 'Proline']
data = pd.read_csv(url, names=cols)

y = data['Class']          # Split off classifications
X = data.ix[:, 'Alcohol':] # Split off features
# Out:
# /Users/Azeem/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:8: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate_ix

# %%
X_norm = (X - X.min())/(X.max() - X.min())

# %%
type(X)
# Out:
# pandas.core.frame.DataFrame

# %%
pca = sklearnPCA(n_components=2) #2-dimensional PCA
transformed = pd.DataFrame(pca.fit_transform(X_norm))

# %%
plt.scatter(transformed[y==1][0], transformed[y==1][1], label='Class 1', c='red',marker='s')
plt.scatter(transformed[y==2][0], transformed[y==2][1], label='Class 2', c='blue')
plt.scatter(transformed[y==3][0], transformed[y==3][1], label='Class 3', c='lightgreen')

plt.legend()
plt.show()

# %%
import pandas as pd
import seaborn as sns; sns.set(color_codes=True)
x, y = pd.Series(x, name="x_var"), pd.Series(y, name="y_var")
ax = sns.regplot(x=x, y=y, marker="+")
plt.show()

# %%
tips = sns.load_dataset("tips")
ax = sns.regplot(x="total_bill", y="tip", data=tips)

# %%
import numpy as np; np.random.seed(8)
mean, cov = [4, 6], [(1.5, .7), (.7, 1)]
x, y = np.random.multivariate_normal(mean, cov, 80).T
ax = sns.regplot(x=x, y=y, color="g")

# %%
#regplot from seaborn, configuration
import matplotlib.pyplot as plt
import seaborn as sns
#ajustar el tamano para todos los plots
# %matplotlib inline 
#una vez llamado matplot , se puede ajustar los parametros
plt.rcParams['figure.figsize']= 8,10
#muestra las figuras de matplot
import warnings
warnings.filterwarnings('ignore')
#para desactivar la regresión
#fit regression
vis3=sns.lmplot(data=stats,x='InternetUsers',y='BirthRate',fit_reg=False)

# %%
#getting some columns
Test.columns[47]
Test[Test.columns[1]]=Test[Test.columns[47]]

# %%
ejemplo de pandas haciendo un filtro con una serie, aplicado a un dataframe
plt.scatter(transformed[y==1][0], transformed[y==1][1], label='Class 1', c='red',marker='s')
